# %%
import pandas as pd
import numpy as np

# %%
trainingSetPath = '../../data/attack_classification/training-set.csv'
testSetPath = '../../data/attack_classification/testing-set.csv'
validationSetPath = '../../data/attack_classification/validation-set.csv'

# %%
trainingSet = pd.read_csv(trainingSetPath)
testingSet = pd.read_csv(testSetPath)
validationSet = pd.read_csv(validationSetPath)

# %%
trainingSet['attack_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
testingSet['attack_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
validationSet['attack_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
validationSet['attack_cat'].value_counts().plot(kind='pie', figsize=(15, 15))
# Out:
# <AxesSubplot:ylabel='attack_cat'>
